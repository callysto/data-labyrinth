# %% [markdown]
# ![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)
#
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fdata-labyrinth&branch=main&subPath=provincial-testing/provincial-testing.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/curriculum-notebooks/master/open-in-callysto-button.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>

# %% [markdown]
# # Provincial Testing Data Labyrinth
#
# Welcome to the [Callysto](https://callysto.ca) Provincial Testing Data Labyrinth. This uses a Jupyter notebook and [provincial achievement test data](https://www.alberta.ca/provincial-achievement-tests) data to navigate through data science challenges.
#
# Every year all Alberta students in Grades 6 and 9 write standardized Provincial Achievement Tests. When interpreting results you should be familiar with the [Guidelines for Interpreting Provincial Achievement Tests](https://www.alberta.ca/system/files/educ-guidelines-for-interpreting-pat-multiyear-reports.pdf).
#
# For this labyrinth you will receive a key word to get started. Type your key between the `''` in the code cell below (e.g. `key = 'abc'`) and then click the `▶Run` button.

# %%
key = 'PAT'

import requests
from IPython import get_ipython
def check(query):
    try:
        r = requests.get('https://script.google.com/macros/s/AKfycbyNwWgQZCm7MR0HmNAat5nqnbWxc8YviiwZfiVXW4NNQLdPRjVHgLP3DSVKUmyvY3OE/exec?room=provincial-testing&query='+str(query))
        response = r.json()
        get_ipython().run_cell_magic('markdown', '', response['markdown'])
        get_ipython().set_next_input(response['code'])
    except:
        print('Make sure you have entered the key correctly.')
        get_ipython().set_next_input("key = ''\ncheck(key)")
import pandas as pd
import plotly.express as px
check(key)
# Out:
# # Introduction
#
# Everything is set up and you are ready to begin. Click on the following code cell, then click the `▶Run` button to display the data from the [.

# %%
data = pd.read_excel('https://www.alberta.ca/system/files/custom_downloaded_images/ed-pat-multiyear-province.xlsx', storage_options={'User-Agent': 'Mozilla/5.0'})
display(data)
check('intro')
# Out:
#                                           Course Name  Form  \
# 0                             English Language Arts 6   1.0
# 1                        French Language Arts 6 année   1.0
# 2                                    Français 6 année   1.0
# 3                                       Mathematics 6   1.0
# 4                                       Mathematics 6   1.0
# 5                                  Mathematics 6 (Fr)   1.0
# 6                                           Science 6   1.0
# 7                                           Science 6   1.0
# 8                                      Science 6 (Fr)   1.0
# 9                                    Social Studies 6   1.0
# 10                                   Social Studies 6   1.0
# 11                              Social Studies (Fr) 6   1.0
# 12                            English Language Arts 9   1.0
# 13                       French Language Arts 9 année   1.0
# 14                        K&E English Language Arts 9   1.0
# 15                                   Français 9 année   1.0
# 16                                      Mathematics 9   1.0
# 17                                      Mathematics 9   1.0
# 18                                  K&E Mathematics 9   1.0
# 19                                  K&E Mathematics 9   1.0
# 20                                 Mathematics 9 (Fr)   1.0
# 21                                          Science 9   1.0
# 22                                          Science 9   1.0
# 23                                      K&E Science 9   1.0
# 24                                      K&E Science 9   1.0
# 25                                     Science 9 (Fr)   1.0
# 26                                   Social Studies 9   1.0
# 27                                   Social Studies 9   1.0
# 28                               K&E Social Studies 9   1.0
# 29                               K&E Social Studies 9   1.0
# 30                              Social Studies (Fr) 9   1.0
# 31                                                NaN   NaN
# 32                                                NaN   NaN
# 33  1. Security breaches occurred over last few da...   NaN
#
#                 Language  2019 Prov Enrol  2019 Prov Writing  \
# 0     Written in English          54820.0            49639.0
# 1      Written in French           3559.0             3479.0
# 2      Written in French            663.0              642.0
# 3   All Students Writing          54778.0            49753.0
# 4     Written in English          50568.0            45625.0
# 5      Written in French           4210.0             4128.0
# 6   All Students Writing          54879.0            49793.0
# 7     Written in English          50659.0            45663.0
# 8      Written in French           4220.0             4130.0
# 9   All Students Writing          54802.0            49670.0
# 10    Written in English          50629.0            45574.0
# 11     Written in French           4173.0             4096.0
# 12    Written in English          47465.0            42002.0
# 13     Written in French           2811.0             2720.0
# 14    Written in English           1569.0             1263.0
# 15     Written in French            396.0              385.0
# 16  All Students Writing          46764.0            41612.0
# 17    Written in English          43834.0            38750.0
# 18  All Students Writing           2190.0             1912.0
# 19    Written in English           2151.0             1874.0
# 20     Written in French           2930.0             2862.0
# 21  All Students Writing          47489.0            42280.0
# 22    Written in English          44541.0            39387.0
# 23  All Students Writing           1536.0             1318.0
# 24    Written in English           1519.0             1302.0
# 25     Written in French           2948.0             2893.0
# 26  All Students Writing          47496.0            42336.0
# 27    Written in English          44373.0            39269.0
# 28  All Students Writing           1466.0             1268.0
# 29    Written in English           1453.0             1256.0
# 30     Written in French           3123.0             3067.0
# 31                   NaN              NaN                NaN
# 32                   NaN              NaN                NaN
# 33                   NaN              NaN                NaN
#
#     2019 Prov Absent  2019 Prov Excused  2019 Prov Acc  2019 Prov Exc  \
# 0             2461.0             2720.0        45618.0         9745.0
# 1               53.0               27.0         3120.0          559.0
# 2                7.0               14.0          599.0          163.0
# 3             2140.0             2885.0        39711.0         8242.0
# 4             2102.0             2841.0        36228.0         7482.0
# 5               38.0               44.0         3483.0          760.0
# 6             2302.0             2784.0        42586.0        15717.0
# 7             2256.0             2740.0        39205.0        14782.0
# 8               46.0               44.0         3381.0          935.0
# 9             2278.0             2854.0        41769.0        13391.0
# 10            2241.0             2814.0        38529.0        12694.0
# 11              37.0               40.0         3240.0          697.0
# 12            2929.0             2534.0        35669.0         7000.0
# 13              75.0               16.0         2329.0          347.0
# 14             225.0               81.0          900.0           85.0
# 15               6.0                5.0          351.0          103.0
# 16            2472.0             2680.0        28065.0         8886.0
# 17            2438.0             2646.0        25752.0         8062.0
# 18             176.0              102.0         1306.0          289.0
# 19             176.0              101.0         1274.0          283.0
# 20              34.0               34.0         2313.0          824.0
# 21            2604.0             2605.0        35711.0        12528.0
# 22            2571.0             2583.0        33138.0        11712.0
# 23             128.0               90.0          948.0          164.0
# 24             127.0               90.0          937.0          164.0
# 25              33.0               22.0         2573.0          816.0
# 26            2504.0             2656.0        32612.0         9766.0
# 27            2472.0             2632.0        30182.0         9053.0
# 28             121.0               77.0          820.0          220.0
# 29             120.0               77.0          811.0          220.0
# 30              32.0               24.0         2430.0          713.0
# 31               NaN                NaN            NaN            NaN
# 32               NaN                NaN            NaN            NaN
# 33               NaN                NaN            NaN            NaN
#
#     2019 Prov Below  ...  2023 Prov % Not Avail  2023 Prov % Acc of Writing  \
# 0            4021.0  ...                   15.8                        90.4
# 1             359.0  ...                    6.6                        83.1
# 2              43.0  ...                   12.3                        89.9
# 3           10042.0  ...                   15.4                        77.4
# 4            9397.0  ...                   16.2                        76.9
# 5             645.0  ...                    6.0                        83.0
# 6            7207.0  ...                   15.8                        79.3
# 7            6458.0  ...                   16.5                        79.9
# 8             749.0  ...                    6.9                        72.3
# 9            7901.0  ...                   15.5                        78.3
# 10           7045.0  ...                   16.2                        79.1
# 11            856.0  ...                    6.0                        68.4
# 12           6333.0  ...                   16.1                        85.1
# 13            391.0  ...                    5.8                        80.8
# 14            363.0  ...                   29.6                        71.2
# 15             34.0  ...                    5.9                        86.7
# 16          13547.0  ...                   16.0                        64.7
# 17          12998.0  ...                   16.8                        64.0
# 18            606.0  ...                   18.5                        64.7
# 19            600.0  ...                   18.9                        65.0
# 20            549.0  ...                    3.9                        74.6
# 21           6569.0  ...                   15.8                        78.8
# 22           6249.0  ...                   16.6                        78.5
# 23            370.0  ...                   21.8                        67.6
# 24            365.0  ...                   22.3                        68.4
# 25            320.0  ...                    4.5                        82.5
# 26           9724.0  ...                   15.8                        69.3
# 27           9087.0  ...                   16.6                        69.0
# 28            448.0  ...                   19.7                        61.9
# 29            445.0  ...                   20.0                        62.1
# 30            637.0  ...                    4.8                        73.0
# 31              NaN  ...                    NaN                         NaN
# 32              NaN  ...                    NaN                         NaN
# 33              NaN  ...                    NaN                         NaN
#
#     2023 Prov % Exc of Writing  2023 Prov % Below of Writing  \
# 0                         21.9                           9.6
# 1                         13.3                          16.9
# 2                         22.1                          10.1
# 3                         18.8                          22.6
# 4                         18.8                          23.1
# 5                         18.8                          17.0
# 6                         25.9                          20.7
# 7                         27.0                          20.1
# 8                         13.7                          27.7
# 9                         21.3                          21.7
# 10                        22.1                          20.9
# 11                        12.4                          31.6
# 12                        15.9                          14.9
# 13                        11.5                          19.2
# 14                         8.0                          28.8
# 15                        23.7                          13.3
# 16                        16.0                          35.3
# 17                        15.6                          36.0
# 18                        13.9                          35.3
# 19                        14.1                          35.0
# 20                        21.6                          25.4
# 21                        23.9                          21.2
# 22                        24.1                          21.5
# 23                        13.9                          32.4
# 24                        14.3                          31.6
# 25                        21.3                          17.5
# 26                        18.9                          30.7
# 27                        19.0                          31.0
# 28                        13.2                          38.1
# 29                        13.3                          37.9
# 30                        16.5                          27.0
# 31                         NaN                           NaN
# 32                         NaN                           NaN
# 33                         NaN                           NaN
#
#     2023 Prov Part 1 % Acc  2023 Prov Part 1 % Exc  2023 Prov Part 2 % Acc  \
# 0                     89.9                    15.3                    88.6
# 1                     83.8                    13.3                    79.8
# 2                     87.2                    24.3                    89.5
# 3                     69.2                    45.4                    78.8
# 4                     68.6                    45.1                    78.4
# 5                     75.4                    48.7                    84.2
# 6                     87.1                    32.1                    74.0
# 7                     87.9                    33.3                    74.3
# 8                     79.0                    17.8                    70.1
# 9                      NaN                     NaN                     NaN
# 10                     NaN                     NaN                     NaN
# 11                     NaN                     NaN                     NaN
# 12                    88.8                    20.1                    80.1
# 13                    87.2                    17.1                    75.3
# 14                    67.4                     5.0                    70.2
# 15                    87.2                    32.0                    83.4
# 16                    48.7                    17.6                    71.3
# 17                    47.6                    17.1                    70.7
# 18                    61.6                    15.9                    69.7
# 19                    61.8                    15.9                    70.1
# 20                    63.5                    24.2                    79.2
# 21                    78.0                    21.6                    80.2
# 22                    77.8                    21.7                    79.9
# 23                    68.2                    15.0                    68.7
# 24                    69.0                    15.3                    69.1
# 25                    80.4                    20.1                    84.7
# 26                     NaN                     NaN                     NaN
# 27                     NaN                     NaN                     NaN
# 28                     NaN                     NaN                     NaN
# 29                     NaN                     NaN                     NaN
# 30                     NaN                     NaN                     NaN
# 31                     NaN                     NaN                     NaN
# 32                     NaN                     NaN                     NaN
# 33                     NaN                     NaN                     NaN
#
#     2023 Prov Part 2 % Exc  2023 Prov Mean %  2023 Prov Std Dev %
# 0                     40.1              67.1                 14.3
# 1                     19.8              63.6                 15.3
# 2                     33.5              70.1                 15.2
# 3                     17.9              65.5                 20.7
# 4                     17.9              65.4                 20.8
# 5                     17.1              66.6                 19.1
# 6                     26.2              63.5                 19.7
# 7                     27.2              63.9                 19.7
# 8                     15.5              58.3                 19.1
# 9                      NaN              63.7                 19.1
# 10                     NaN              64.2                 19.1
# 11                     NaN              57.9                 18.8
# 12                    19.9              65.1                 15.0
# 13                    11.9              66.0                 13.8
# 14                    17.9              60.6                 14.7
# 15                    18.5              71.8                 15.1
# 16                    18.4              57.4                 22.7
# 17                    17.9              56.9                 22.8
# 18                    18.6              60.9                 17.3
# 19                    18.6              61.0                 17.2
# 20                    24.6              64.3                 20.7
# 21                    29.4              62.7                 21.3
# 22                    29.7              62.7                 21.4
# 23                    17.9              58.6                 19.0
# 24                    18.4              58.9                 18.9
# 25                    25.6              63.9                 19.9
# 26                     NaN              58.6                 20.2
# 27                     NaN              58.6                 20.4
# 28                     NaN              58.1                 19.2
# 29                     NaN              58.2                 19.3
# 30                     NaN              57.7                 18.3
# 31                     NaN               NaN                  NaN
# 32                     NaN               NaN                  NaN
# 33                     NaN               NaN                  NaN
#
# [34 rows x 143 columns]

# %%
print(data.iloc[-1][0])
# Out:
# 1. Security breaches occurred over last few days of the 2021-22 PAT administration window for a few Grade 9 courses including English Language Arts, Mathematics, Science and Social Studies. To maintain the validity and comparability of provincial results, students most likely impacted by these security breaches in those courses have been excluded from the provincial cohort. However, all students have been included in school and school authority reporting and, therefore, caution should be exercised when interpreting these results.
# 2. Due to the COVID-19 pandemic, no reportable data is available for the 2019/2020 and the 2020/2021 school years.
# 3. Given that the number of students who wrote the Knowledge and Employability Examinations (KAE) in French is too small province-wide, provincial results written in French are not reported. For the comparison purpose, the corresponding provincial results for all students may be used.
# 4. The 2022/2023 results do not include students who were exempted from writing the test because of the northern Alberta wildfires.
# 5. The 2022/2023 results do not include students who participated in the optionally implemented/piloted curriculum and were excused from writing the grade 6 PATs in those subject areas being optionally implemented/piloted.

# %%
display(data['Course Name'].unique())
check('cleaning')
# Out:
# array(['English Language Arts 6', 'French Language Arts 6 année',
#        'Français 6 année', 'Mathematics 6', 'Mathematics 6 (Fr)',
#        'Science 6', 'Science 6 (Fr)', 'Social Studies 6',
#        'Social Studies (Fr) 6', 'English Language Arts 9',
#        'French Language Arts 9 année', 'K&E English Language Arts 9',
#        'Français 9 année', 'Mathematics 9', 'K&E Mathematics 9',
#        'Mathematics 9 (Fr)', 'Science 9', 'K&E Science 9',
#        'Science 9 (Fr)', 'Social Studies 9', 'K&E Social Studies 9',
#        'Social Studies (Fr) 9', nan,
#        '1. Security breaches occurred over last few days of the 2021-22 PAT administration window for a few Grade 9 courses including English Language Arts, Mathematics, Science and Social Studies. To maintain the validity and comparability of provincial results, students most likely impacted by these security breaches in those courses have been excluded from the provincial cohort. However, all students have been included in school and school authority reporting and, therefore, caution should be exercised when interpreting these results.\n2. Due to the COVID-19 pandemic, no reportable data is available for the 2019/2020 and the 2020/2021 school years.\n3. Given that the number of students who wrote the Knowledge and Employability Examinations (KAE) in French is too small province-wide, provincial results written in French are not reported. For the comparison purpose, the corresponding provincial results for all students may be used.\n4. The 2022/2023 results do not include students who were exempted from writing the test because of the northern Alberta wildfires.\n5. The 2022/2023 results do not include students who participated in the optionally implemented/piloted curriculum and were excused from writing the grade 6 PATs in those subject areas being optionally implemented/piloted.\n '],
#       dtype=object)

# %%
data = data.dropna(subset=['Course Name'])
data = data.iloc[:-1]
display(data)
check('cleaned')
# Out:
#                      Course Name  Form              Language  2019 Prov Enrol  \
# 0        English Language Arts 6   1.0    Written in English          54820.0
# 1   French Language Arts 6 année   1.0     Written in French           3559.0
# 2               Français 6 année   1.0     Written in French            663.0
# 3                  Mathematics 6   1.0  All Students Writing          54778.0
# 4                  Mathematics 6   1.0    Written in English          50568.0
# 5             Mathematics 6 (Fr)   1.0     Written in French           4210.0
# 6                      Science 6   1.0  All Students Writing          54879.0
# 7                      Science 6   1.0    Written in English          50659.0
# 8                 Science 6 (Fr)   1.0     Written in French           4220.0
# 9               Social Studies 6   1.0  All Students Writing          54802.0
# 10              Social Studies 6   1.0    Written in English          50629.0
# 11         Social Studies (Fr) 6   1.0     Written in French           4173.0
# 12       English Language Arts 9   1.0    Written in English          47465.0
# 13  French Language Arts 9 année   1.0     Written in French           2811.0
# 14   K&E English Language Arts 9   1.0    Written in English           1569.0
# 15              Français 9 année   1.0     Written in French            396.0
# 16                 Mathematics 9   1.0  All Students Writing          46764.0
# 17                 Mathematics 9   1.0    Written in English          43834.0
# 18             K&E Mathematics 9   1.0  All Students Writing           2190.0
# 19             K&E Mathematics 9   1.0    Written in English           2151.0
# 20            Mathematics 9 (Fr)   1.0     Written in French           2930.0
# 21                     Science 9   1.0  All Students Writing          47489.0
# 22                     Science 9   1.0    Written in English          44541.0
# 23                 K&E Science 9   1.0  All Students Writing           1536.0
# 24                 K&E Science 9   1.0    Written in English           1519.0
# 25                Science 9 (Fr)   1.0     Written in French           2948.0
# 26              Social Studies 9   1.0  All Students Writing          47496.0
# 27              Social Studies 9   1.0    Written in English          44373.0
# 28          K&E Social Studies 9   1.0  All Students Writing           1466.0
# 29          K&E Social Studies 9   1.0    Written in English           1453.0
#
#     2019 Prov Writing  2019 Prov Absent  2019 Prov Excused  2019 Prov Acc  \
# 0             49639.0            2461.0             2720.0        45618.0
# 1              3479.0              53.0               27.0         3120.0
# 2               642.0               7.0               14.0          599.0
# 3             49753.0            2140.0             2885.0        39711.0
# 4             45625.0            2102.0             2841.0        36228.0
# 5              4128.0              38.0               44.0         3483.0
# 6             49793.0            2302.0             2784.0        42586.0
# 7             45663.0            2256.0             2740.0        39205.0
# 8              4130.0              46.0               44.0         3381.0
# 9             49670.0            2278.0             2854.0        41769.0
# 10            45574.0            2241.0             2814.0        38529.0
# 11             4096.0              37.0               40.0         3240.0
# 12            42002.0            2929.0             2534.0        35669.0
# 13             2720.0              75.0               16.0         2329.0
# 14             1263.0             225.0               81.0          900.0
# 15              385.0               6.0                5.0          351.0
# 16            41612.0            2472.0             2680.0        28065.0
# 17            38750.0            2438.0             2646.0        25752.0
# 18             1912.0             176.0              102.0         1306.0
# 19             1874.0             176.0              101.0         1274.0
# 20             2862.0              34.0               34.0         2313.0
# 21            42280.0            2604.0             2605.0        35711.0
# 22            39387.0            2571.0             2583.0        33138.0
# 23             1318.0             128.0               90.0          948.0
# 24             1302.0             127.0               90.0          937.0
# 25             2893.0              33.0               22.0         2573.0
# 26            42336.0            2504.0             2656.0        32612.0
# 27            39269.0            2472.0             2632.0        30182.0
# 28             1268.0             121.0               77.0          820.0
# 29             1256.0             120.0               77.0          811.0
#
#     2019 Prov Exc  2019 Prov Below  ...  2023 Prov % Not Avail  \
# 0          9745.0           4021.0  ...                   15.8
# 1           559.0            359.0  ...                    6.6
# 2           163.0             43.0  ...                   12.3
# 3          8242.0          10042.0  ...                   15.4
# 4          7482.0           9397.0  ...                   16.2
# 5           760.0            645.0  ...                    6.0
# 6         15717.0           7207.0  ...                   15.8
# 7         14782.0           6458.0  ...                   16.5
# 8           935.0            749.0  ...                    6.9
# 9         13391.0           7901.0  ...                   15.5
# 10        12694.0           7045.0  ...                   16.2
# 11          697.0            856.0  ...                    6.0
# 12         7000.0           6333.0  ...                   16.1
# 13          347.0            391.0  ...                    5.8
# 14           85.0            363.0  ...                   29.6
# 15          103.0             34.0  ...                    5.9
# 16         8886.0          13547.0  ...                   16.0
# 17         8062.0          12998.0  ...                   16.8
# 18          289.0            606.0  ...                   18.5
# 19          283.0            600.0  ...                   18.9
# 20          824.0            549.0  ...                    3.9
# 21        12528.0           6569.0  ...                   15.8
# 22        11712.0           6249.0  ...                   16.6
# 23          164.0            370.0  ...                   21.8
# 24          164.0            365.0  ...                   22.3
# 25          816.0            320.0  ...                    4.5
# 26         9766.0           9724.0  ...                   15.8
# 27         9053.0           9087.0  ...                   16.6
# 28          220.0            448.0  ...                   19.7
# 29          220.0            445.0  ...                   20.0
#
#     2023 Prov % Acc of Writing  2023 Prov % Exc of Writing  \
# 0                         90.4                        21.9
# 1                         83.1                        13.3
# 2                         89.9                        22.1
# 3                         77.4                        18.8
# 4                         76.9                        18.8
# 5                         83.0                        18.8
# 6                         79.3                        25.9
# 7                         79.9                        27.0
# 8                         72.3                        13.7
# 9                         78.3                        21.3
# 10                        79.1                        22.1
# 11                        68.4                        12.4
# 12                        85.1                        15.9
# 13                        80.8                        11.5
# 14                        71.2                         8.0
# 15                        86.7                        23.7
# 16                        64.7                        16.0
# 17                        64.0                        15.6
# 18                        64.7                        13.9
# 19                        65.0                        14.1
# 20                        74.6                        21.6
# 21                        78.8                        23.9
# 22                        78.5                        24.1
# 23                        67.6                        13.9
# 24                        68.4                        14.3
# 25                        82.5                        21.3
# 26                        69.3                        18.9
# 27                        69.0                        19.0
# 28                        61.9                        13.2
# 29                        62.1                        13.3
#
#     2023 Prov % Below of Writing  2023 Prov Part 1 % Acc  \
# 0                            9.6                    89.9
# 1                           16.9                    83.8
# 2                           10.1                    87.2
# 3                           22.6                    69.2
# 4                           23.1                    68.6
# 5                           17.0                    75.4
# 6                           20.7                    87.1
# 7                           20.1                    87.9
# 8                           27.7                    79.0
# 9                           21.7                     NaN
# 10                          20.9                     NaN
# 11                          31.6                     NaN
# 12                          14.9                    88.8
# 13                          19.2                    87.2
# 14                          28.8                    67.4
# 15                          13.3                    87.2
# 16                          35.3                    48.7
# 17                          36.0                    47.6
# 18                          35.3                    61.6
# 19                          35.0                    61.8
# 20                          25.4                    63.5
# 21                          21.2                    78.0
# 22                          21.5                    77.8
# 23                          32.4                    68.2
# 24                          31.6                    69.0
# 25                          17.5                    80.4
# 26                          30.7                     NaN
# 27                          31.0                     NaN
# 28                          38.1                     NaN
# 29                          37.9                     NaN
#
#     2023 Prov Part 1 % Exc  2023 Prov Part 2 % Acc  2023 Prov Part 2 % Exc  \
# 0                     15.3                    88.6                    40.1
# 1                     13.3                    79.8                    19.8
# 2                     24.3                    89.5                    33.5
# 3                     45.4                    78.8                    17.9
# 4                     45.1                    78.4                    17.9
# 5                     48.7                    84.2                    17.1
# 6                     32.1                    74.0                    26.2
# 7                     33.3                    74.3                    27.2
# 8                     17.8                    70.1                    15.5
# 9                      NaN                     NaN                     NaN
# 10                     NaN                     NaN                     NaN
# 11                     NaN                     NaN                     NaN
# 12                    20.1                    80.1                    19.9
# 13                    17.1                    75.3                    11.9
# 14                     5.0                    70.2                    17.9
# 15                    32.0                    83.4                    18.5
# 16                    17.6                    71.3                    18.4
# 17                    17.1                    70.7                    17.9
# 18                    15.9                    69.7                    18.6
# 19                    15.9                    70.1                    18.6
# 20                    24.2                    79.2                    24.6
# 21                    21.6                    80.2                    29.4
# 22                    21.7                    79.9                    29.7
# 23                    15.0                    68.7                    17.9
# 24                    15.3                    69.1                    18.4
# 25                    20.1                    84.7                    25.6
# 26                     NaN                     NaN                     NaN
# 27                     NaN                     NaN                     NaN
# 28                     NaN                     NaN                     NaN
# 29                     NaN                     NaN                     NaN
#
#     2023 Prov Mean %  2023 Prov Std Dev %
# 0               67.1                 14.3
# 1               63.6                 15.3
# 2               70.1                 15.2
# 3               65.5                 20.7
# 4               65.4                 20.8
# 5               66.6                 19.1
# 6               63.5                 19.7
# 7               63.9                 19.7
# 8               58.3                 19.1
# 9               63.7                 19.1
# 10              64.2                 19.1
# 11              57.9                 18.8
# 12              65.1                 15.0
# 13              66.0                 13.8
# 14              60.6                 14.7
# 15              71.8                 15.1
# 16              57.4                 22.7
# 17              56.9                 22.8
# 18              60.9                 17.3
# 19              61.0                 17.2
# 20              64.3                 20.7
# 21              62.7                 21.3
# 22              62.7                 21.4
# 23              58.6                 19.0
# 24              58.9                 18.9
# 25              63.9                 19.9
# 26              58.6                 20.2
# 27              58.6                 20.4
# 28              58.1                 19.2
# 29              58.2                 19.3
#
# [30 rows x 143 columns]
# Make sure you have entered the key correctly.

# %%
course = 'Science 9'


filtered_data = data[data['Course Name'] == course]
px.scatter(filtered_data, y='Course Name', x='Language')
