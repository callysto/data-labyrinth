# %% [markdown]
# ![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)
#
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fdata-labyrinth&branch=main&subPath=cybersecurity/cybersecurity.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/curriculum-notebooks/master/open-in-callysto-button.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>
#
# <a target="_parent" href="https://2i2c.callysto.ca/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fdata-labyrinth&branch=main&subPath=cybersecurity/cybersecurity.ipynb&depth=1"><img src="https://2i2c.org/media/logo.svg" width="30" height="30" alt="Open in 2i2c Hub"/></a>

# %% [markdown]
# # Cybersecurity Data Labyrinth
#
# Welcome to the [Callysto](https://callysto.ca) Cybersecurity Data Labyrinth. This uses a Jupyter notebook with data and scenarios from [Splunk](https://www.splunk.com) to navigate through data science challenges.
#
# You will receive a key word to initiate this labyrinth. Type your key between the `''` in the code cell below (e.g. `key = 'abc'`) and then click the `▶Run` button to get started.

# %%
key = ''

from data.start import start
start(key)

# %%
import requests
import pandas as pd
import gzip
import io
import json

r = requests.get('https://s3.amazonaws.com/botsdataset/botsv1/csv-by-sourcetype/botsv1.stream%3Ahttp.csv.gz')
df = pd.read_csv(gzip.GzipFile(fileobj=io.BytesIO(r.content)))

# %%
from data.start import cleaning
data = cleaning(df)
display(data)
check('cleaned')
# Out:
#                            endtime                    timestamp  \
# 0      2016-08-28T23:54:58.348077Z  2016-08-28T23:54:58.240395Z
# 1      2016-08-28T23:51:26.774611Z  2016-08-28T23:51:26.586434Z
# 2      2016-08-28T23:42:51.829325Z  2016-08-28T23:42:51.696250Z
# 3      2016-08-28T23:39:21.803892Z  2016-08-28T23:39:21.639478Z
# 4      2016-08-28T23:38:57.695883Z  2016-08-28T23:38:57.555942Z
# ...                            ...                          ...
# 39005  2016-08-01T00:06:56.469821Z  2016-08-01T00:06:56.324428Z
# 39006  2016-08-01T00:06:45.298302Z  2016-08-01T00:06:45.154127Z
# 39007  2016-08-01T00:05:16.695883Z  2016-08-01T00:05:16.555942Z
# 39008  2016-08-01T00:05:06.647150Z  2016-08-01T00:05:06.466001Z
# 39009  2016-08-01T00:01:01.929874Z  2016-08-01T00:01:01.821956Z
#
#       ack_packets_in ack_packets_out bytes bytes_in bytes_out  \
# 0                  5               4  4900      213      4687
# 1                  3               8  2162     1984       178
# 2                  3               4   518      286       232
# 3                  3               8  2162     1984       178
# 4                  3               8  2162     1984       178
# ...              ...             ...   ...      ...       ...
# 39005              3               8  2162     1984       178
# 39006              3               8  2162     1984       178
# 39007              3               8  2162     1984       178
# 39008              3               8  2162     1984       178
# 39009              3               4   340      189       151
#
#                   c_ip cached capture_hostname  ... location sc_pragma  \
# 0      192.168.250.100      0          demo-01  ...      NaN       NaN
# 1      192.168.250.100      0          demo-01  ...      NaN       NaN
# 2       192.168.250.20      1          demo-01  ...      NaN       NaN
# 3      192.168.250.100      0          demo-01  ...      NaN       NaN
# 4      192.168.250.100      0          demo-01  ...      NaN       NaN
# ...                ...    ...              ...  ...      ...       ...
# 39005  192.168.250.100      0          demo-01  ...      NaN       NaN
# 39006  192.168.250.100      0          demo-01  ...      NaN       NaN
# 39007  192.168.250.100      0          demo-01  ...      NaN       NaN
# 39008  192.168.250.100      0          demo-01  ...      NaN       NaN
# 39009  192.168.250.100      0          demo-01  ...      NaN       NaN
#
#       refused content_disposition part_filename content_location age allow  \
# 0         NaN                 NaN           NaN              NaN NaN   NaN
# 1         NaN                 NaN           NaN              NaN NaN   NaN
# 2         NaN                 NaN           NaN              NaN NaN   NaN
# 3         NaN                 NaN           NaN              NaN NaN   NaN
# 4         NaN                 NaN           NaN              NaN NaN   NaN
# ...       ...                 ...           ...              ...  ..   ...
# 39005     NaN                 NaN           NaN              NaN NaN   NaN
# 39006     NaN                 NaN           NaN              NaN NaN   NaN
# 39007     NaN                 NaN           NaN              NaN NaN   NaN
# 39008     NaN                 NaN           NaN              NaN NaN   NaN
# 39009     NaN                 NaN           NaN              NaN NaN   NaN
#
#       user uri_parm
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
# ...    ...      ...
# 39005  NaN      NaN
# 39006  NaN      NaN
# 39007  NaN      NaN
# 39008  NaN      NaN
# 39009  NaN      NaN
#
# [39010 rows x 85 columns]
